# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
imag_path = '/content/drive/MyDrive/Computer Vision/openCV/people.jpg'

# %%
pip install opencv-python

# %%
import cv2

# %%
image = cv2.imread(imag_path)

# %%
image.shape
# Out:
# (408, 612, 3)

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_img.shape
# Out:
# (408, 612)

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=612x408>

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'harrcascade_frontalface_default.xml'
)

# %%
# face = face_classifier.detectMultiScale(gray_img, scaleFactor = 1.1 , minNeighbors = 5, minSize = (40,40))

# %%
# face = face_classifier.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40))

# %%
import cv2
from google.colab.patches import cv2_imshow

imag_path = '/content/drive/MyDrive/Computer Vision/openCV/people.jpg'

# 1. Verify image path and loading:
# Print the image path to confirm it's correct
print("Image Path:", imag_path)

# Try loading the image in color first to see if it loads correctly
image = cv2.imread(imag_path, cv2.IMREAD_COLOR)

# Check if the image loaded successfully
if image is None:
    print("Error: Could not load image. Please check the image path.")
else:
    # 2. If the image loads, proceed with grayscale conversion
    gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # 3. Display the grayscale image to visually check if it's empty
    # cv2_imshow(gray_img)

    # 4. Now try face detection
    face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    face = face_classifier.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40))

    # Print the number of faces detected to see if it worked
    print("Number of faces detected:", len(face))
# Out:
# Image Path: /content/drive/MyDrive/Computer Vision/openCV/people.jpg
# Number of faces detected: 1

# %%
face
# Out:
# array([[308,  97,  52,  52]], dtype=int32)

# %%
for (x,y,w,h) in face:
  cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>
